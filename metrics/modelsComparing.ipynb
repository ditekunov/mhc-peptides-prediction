# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
mhc_based_models = ['Bagged decision tree','KNN classifier with 3 NN', 'KNN classifier with 2 NN',
                    'Random forest with 6000 trees', 
                    'Random forest with 900 trees',
                    'Decision tree', 'Logistic regression',  'KNN classifier with 10 NN']

mhc_models_acc = [85.8888, 78.9030, 80.2825, 84.5680, 84.5570, 81.9189, 77.2152, 78.6461]

print("Accuracy of mhc-based models:")
sns.barplot(x=mhc_based_models, y=mhc_models_acc)
plt.show()
# Out:
# Accuracy of mhc-based models:

# %%
mhc_based_models = ['Bagged decision tree',
                    'Random forest with 6000 trees', 
                    'Random forest with 900 trees',
                    'Decision tree', 'Logistic regression']

mhc_models_auc = [89.9404, 73.4058, 73.3703, 74.7383, 58.4311]

print("AUC-ROC of mhc-based models:")
sns.barplot(x=mhc_based_models, y=mhc_models_auc)
plt.show()
# Out:
# AUC-ROC of mhc-based models:

# %%
mhc_based_models = ['Bagged decision tree','KNN classifier with 3 NN', 'KNN classifier with 2 NN',
                    'Random forest with 6000 trees', 
                    'Random forest with 900 trees',
                    'Decision tree',  'KNN classifier with 10 NN']

mhc_models_f = [66.2836, 72.1252, 67.8703, 60.9688, 60.9156, 60.8018, 38.5544]

print("F-measure of mhc-based models:")
sns.barplot(x=mhc_based_models, y=mhc_models_f)
plt.show()
# Out:
# F-measure of mhc-based models:

# %%
meas_models = ['KNN classifier with 1 NN', 'Bootstrapped decision tree',
               'Decision tree', 'Logistic regression', 'Random forest with 80 trees',
               'Linear regression']

meas_models_acc = [99.8862, 99.8863, 99.8863, 99.8936, 99.8863, 80.7395]

print("Accuracy of meas-based models:")
sns.barplot(x=meas_models, y=meas_models_acc)
plt.show()
# Out:
# Accuracy of meas-based models:

# %%
meas_models = ['Bootstrapped decision tree',
               'Decision tree', 'Logistic regression', 'Random forest with 80 trees']

meas_models_auc = [99.9998, 99.9264, 99.9311, 99.9264]

print("AUC-ROC of meas-based models:")
sns.barplot(x=meas_models, y=meas_models_auc)
plt.show()
# Out:
# AUC-ROC of meas-based models:

# %%
meas_models = ['KNN classifier with 1 NN', 'Bootstrapped decision tree',
               'Decision tree', 'Logistic regression', 'Random forest with 80 trees',
               'Linear regression']

meas_models_f = [99.9998, 99.7504, 99.7504,99.7504, 99.7664, 99.7504, 99.7304]

print("Accuracy of meas-based models:")
sns.barplot(x=meas_models, y=meas_models_f)
plt.show()
# Out:
# Accuracy of meas-based models:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-6b64f7e7d830> in <module>()
#       6
#       7 print("Accuracy of meas-based models:")
# ----> 8 sns.barplot(x=meas_models, y=meas_models_f)
#       9 plt.show()
#
# /usr/local/lib/python3.6/site-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    2957                           estimator, ci, n_boot, units,
#    2958                           orient, color, palette, saturation,
# -> 2959                           errcolor, errwidth, capsize, dodge)
#    2960
#    2961     if ax is None:
#
# ...
